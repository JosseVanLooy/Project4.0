# %%
pip install librosa
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: librosa in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (0.9.2)
# Requirement already satisfied: pooch>=1.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.6.0)
# Requirement already satisfied: scikit-learn>=0.19.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.1.2)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (3.0.0)
# Requirement already satisfied: resampy>=0.2.2 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.4.2)
# Requirement already satisfied: soundfile>=0.10.2 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.11.0)
# Requirement already satisfied: numba>=0.45.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (0.56.4)
# Requirement already satisfied: scipy>=1.2.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.9.2)
# Requirement already satisfied: joblib>=0.14 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (21.3)
# Requirement already satisfied: decorator>=4.0.10 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (5.1.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from librosa) (1.23.3)
# Requirement already satisfied: setuptools in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.45.1->librosa) (63.2.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.45.1->librosa) (0.39.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->librosa) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from pooch>=1.0->librosa) (2.28.1)
# Requirement already satisfied: appdirs>=1.3.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from pooch>=1.0->librosa) (1.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn>=0.19.1->librosa) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from soundfile>=0.10.2->librosa) (1.15.1)
# Requirement already satisfied: pycparser in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa) (2.21)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.19.0->pooch>=1.0->librosa) (3.4)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (0.12.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.6.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.23.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.37.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.25->seaborn) (2022.4)
# Requirement already satisfied: six>=1.5 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.23.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.23.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.49.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: setuptools in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (63.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (22.9.24)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: packaging in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorflow) (21.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.37.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.12.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from packaging->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.7.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (1.26.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\josse\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\josse\appdata\local\programs\python\python310\lib\site-packages)
#
# [notice] A new release of pip available: 22.2.2 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import IPython.display as ipd
filepath = "input/UrbanSound8K/audio/fold1/103074-7-0-0.wav"
ipd.Audio(filepath, rate=2250)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt
data, sample_rate = librosa.load(filepath)
plt.figure(figsize=(12, 5))
librosa.display.waveshow(data, sr=sample_rate)

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio = wav.read(filepath)
print(wave_sample_rate)
print(wave_audio)
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 4))
plt.plot(wave_audio)
# Out:
# 48000
# [[ 1307136  8273920]
#  [ 3883776 10120448]
#  [ 7894528 12678400]
#  ...
#  [82106368 30823680]
#  [71655168 30478336]
#  [58807040 24245760]]
# [<matplotlib.lines.Line2D at 0x26e88cfd270>,
#  <matplotlib.lines.Line2D at 0x26e88cfd2d0>]

# %%
import pandas as pd
metadata = pd.read_csv('input/urbansound8k/metadata/UrbanSound8K.csv')
metadata.head(10)
# Out:
#       slice_file_name    fsID      start        end  salience  fold  classID  \
# 0    100032-3-0-0.wav  100032   0.000000   0.317551         1     5        3
# 1  100263-2-0-117.wav  100263  58.500000  62.500000         1     5        2
# 2  100263-2-0-121.wav  100263  60.500000  64.500000         1     5        2
# 3  100263-2-0-126.wav  100263  63.000000  67.000000         1     5        2
# 4  100263-2-0-137.wav  100263  68.500000  72.500000         1     5        2
# 5  100263-2-0-143.wav  100263  71.500000  75.500000         1     5        2
# 6  100263-2-0-161.wav  100263  80.500000  84.500000         1     5        2
# 7    100263-2-0-3.wav  100263   1.500000   5.500000         1     5        2
# 8   100263-2-0-36.wav  100263  18.000000  22.000000         1     5        2
# 9    100648-1-0-0.wav  100648   4.823402   5.471927         2    10        1
#
#               class
# 0          dog_bark
# 1  children_playing
# 2  children_playing
# 3  children_playing
# 4  children_playing
# 5  children_playing
# 6  children_playing
# 7  children_playing
# 8  children_playing
# 9          car_horn

# %%
mfccs = librosa.feature.mfcc(y=data, sr=sample_rate, n_mfcc=40)
print(mfccs.shape)
print(mfccs)
# Out:
# (40, 173)
# [[-3.2764008e+02 -2.8665390e+02 -2.9000211e+02 ... -1.5311163e+02
#   -1.5024710e+02 -1.9375616e+02]
#  [ 1.5112079e+02  1.4891867e+02  1.5038649e+02 ...  8.1661575e+01
#    8.0324356e+01  8.6650078e+01]
#  [-1.2752694e+01 -1.1159609e+01 -1.6118874e+01 ... -2.0785460e+00
#   -4.1884894e+00 -7.5812840e+00]
#  ...
#  [ 2.4731266e+00  2.0393348e+00 -1.9266342e+00 ...  6.8323040e+00
#    6.6275740e+00  6.8086171e+00]
#  [-2.8748839e+00 -4.7827277e+00 -4.4166856e+00 ... -8.7984295e+00
#   -1.0455021e+01 -1.4884484e+00]
#  [-2.4049296e+00  8.8420987e-02  1.8874354e+00 ...  2.5747464e+00
#   -4.9162402e+00  1.7375057e+00]]

# %%
def features_extractor(file):
    #load the file (audio)
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    #we extract mfcc
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    #in order to find out scaled feature we do mean of transpose of value
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    return mfccs_scaled_features

# %%
#Now we ned to extract the featured from all the audio files so we use tqdm
import numpy as np
from tqdm import tqdm
### Now we iterate through every audio file and extract features 
### using Mel-Frequency Cepstral Coefficients
extracted_features=[]
for index_num,row in tqdm(metadata.iterrows()):
    file_name = os.path.join(os.path.abspath('input/Urbansound8K/audio'),'fold'+str(row["fold"])+'\\',str(row["slice_file_name"]))
    final_class_labels=row["class"]
    data=features_extractor(file_name)
    extracted_features.append([data,final_class_labels])
# Out:
# 151it [00:07, 21.55it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [43], line 10
#       8 file_name = os.path.join(os.path.abspath('input/Urbansound8K/audio'),'fold'+str(row["fold"])+'\\',str(row["slice_file_name"]))
#       9 final_class_labels=row["class"]
# ---> 10 data=features_extractor(file_name)
#      11 extracted_features.append([data,final_class_labels])
#
# Cell In [40], line 3, in features_extractor(file)
#       1 def features_extractor(file):
#       2     #load the file (audio)
# ----> 3     audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
#       4     #we extract mfcc
#       5     mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
#
# File c:\Users\josse\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File c:\Users\josse\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\core\audio.py:179, in load(path, sr, mono, offset, duration, dtype, res_type)
#     176     y = to_mono(y)
#     178 if sr is not None:
# --> 179     y = resample(y, orig_sr=sr_native, target_sr=sr, res_type=res_type)
#     181 else:
#     182     sr = sr_native
#
# File c:\Users\josse\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\util\decorators.py:88, in deprecate_positional_args.<locals>._inner_deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      86 extra_args = len(args) - len(all_args)
#      87 if extra_args <= 0:
# ---> 88     return f(*args, **kwargs)
#      90 # extra_args > 0
#      91 args_msg = [
#      92     "{}={}".format(name, arg)
#      93     for name, arg in zip(kwonly_args[:extra_args], args[-extra_args:])
#      94 ]
#
# File c:\Users\josse\AppData\Local\Programs\Python\Python310\lib\site-packages\librosa\core\audio.py:647, in resample(y, orig_sr, target_sr, res_type, fix, scale, **kwargs)
#     645     y_hat = soxr.resample(y.T, orig_sr, target_sr, quality=res_type).T
#     646 else:
# --> 647     y_hat = resampy.resample(y, orig_sr, target_sr, filter=res_type, axis=-1)
#     649 if fix:
#     650     y_hat = util.fix_length(y_hat, size=n_samples, **kwargs)
#
# File c:\Users\josse\AppData\Local\Programs\Python\Python310\lib\site-packages\resampy\core.py:168, in resample(x, sr_orig, sr_new, axis, filter, parallel, **kwargs)
#     158         resample_f_s(
#     159             x.swapaxes(-1, axis),
#     160             t_out,
#    (...)
#     165             y.swapaxes(-1, axis),
#     166         )
#     167 else:
# --> 168     resample_f_s(
#     169         x.swapaxes(-1, axis),
#     170         t_out,
#     171         interp_win,
#     172         interp_delta,
#     173         precision,
#     174         scale,
#     175         y.swapaxes(-1, axis),
#     176     )
#     178 return y
#
# File c:\Users\josse\AppData\Local\Programs\Python\Python310\lib\site-packages\numba\np\ufunc\gufunc.py:192, in GUFunc.__call__(self, *args, **kwargs)
#     190     self.add(sig)
#     191     self.build_ufunc()
# --> 192 return self.ufunc(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
### converting extracted_features to Pandas dataframe
extracted_features_df=pd.DataFrame(extracted_features,columns=['feature','class'])
extracted_features_df.head()

# %%
### Split the dataset into independent and dependent dataset
X=np.array(extracted_features_df['feature'].tolist())
y=np.array(extracted_features_df['class'].tolist())
### Label Encoding -> Label Encoder
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
y=to_categorical(labelencoder.fit_transform(y))
### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics
### No of classes
num_labels=y.shape[1]

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###final layer
model.add(Dense(num_labels))
model.add(Activation('softmax'))

# %%
model.compile(loss='categorical_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
## Trianing my model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 
num_epochs = 100
num_batch_size = 32
checkpointer = ModelCheckpoint(filepath='./audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()
model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)
duration = datetime.now() - start
print("Training completed in time: ", duration)

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])

# %%
#model.predict_classes(X_test)
predict_x=model.predict(X_test) 
classes_x=np.argmax(predict_x,axis=1)
print(classes_x)

# %%
filename="../input/urbansound8k/fold7/101848-9-0-0.wav"
#preprocess the audio file
audio, sample_rate = librosa.load(filename, res_type='kaiser_fast') 
mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
#Reshape MFCC feature to 2-D array
mfccs_scaled_features=mfccs_scaled_features.reshape(1,-1)
#predicted_label=model.predict_classes(mfccs_scaled_features)
x_predict=model.predict(mfccs_scaled_features) 
predicted_label=np.argmax(x_predict,axis=1)
print(predicted_label)
prediction_class = labelencoder.inverse_transform(predicted_label) 
print(prediction_class)
